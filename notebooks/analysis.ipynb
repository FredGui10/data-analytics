# %%
import pandas as pd

data = {
    "name": ["Alice", "Bob", "Charlie"],
    "score": [85, 92, 78]
}

df = pd.DataFrame(data)
df
# Out:
#       name  score
# 0    Alice     85
# 1      Bob     92
# 2  Charlie     78
